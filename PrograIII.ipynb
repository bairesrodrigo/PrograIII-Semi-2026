# %% [markdown]
# <a href="https://colab.research.google.com/github/bairesrodrigo/PrograIII-Semi-2026/blob/main/PrograIII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("20 + 20 + 20 + 7, eso es muy facil profesora es:")

a = "6"
b = "7"
c = a + b

print(c)
# Out:
# 20 + 20 + 20 + 7, eso es muy facil profesora es:
# 67

# %%
saludo = "Hola, chicos de progra III"

print(saludo, "Primera letra del saludo", saludo[0:4])

num1 = 5.25

print(num1)
# Out:
# Hola, chicos de progra III Primera letra del saludo Hola
# 5.25

# %%
print("Sumar dos números: ")

num1 = input("Num1: ")
num2 = input("Num2: ")

respuesta = float(num1) + float(num2)

print("Respuesta: ", respuesta)
# Out:
# Sumar dos números:
# Num1: 30
# Num2: 37
# Respuesta:  67.0

# %%
print("Restar dos números: ")

num1 = input("Num1: ")
num2 = input("Num2: ")

respuesta = float(num1) - float(num2)

print("Respuesta: ", respuesta)
# Out:
# Restar dos números:
# Num1: 120
# Num2: 57
# Respuesta:  63.0

# %%
print("Multiplicar dos números: ")

num1 = input("Num1: ")
num2 = input("Num2: ")

respuesta = float(num1) * float(num2)

print("Respuesta: ", respuesta)
# Out:
# Multiplicar dos números:
# Num1: 6
# Num2: 6
# Respuesta:  36.0

# %%
print("Dividir dos números: ")

num1 = input("Num1: ")
num2 = input("Num2: ")

respuesta = float(num1) / float(num2)

print("Respuesta: ", respuesta)
# Out:
# Dividir dos números:
# Num1: 9
# Num2: 3
# Respuesta:  3.0

# %%
saludo = "¡Hola a todos, y bienvenidos a iTownGamePlay! Vuestro canal de terror... y diversión"

print(saludo)
print("Primer elemento de la cadena", saludo[0:4])
print("Rango de una cadena", saludo[0:4])
print("Ultimo elemento", saludo[-1])
print("Ulitmo elemento", saludo[len(saludo)-1])
print("Valores en medio, sin especificar ultimo valor", saludo[5:])
print("Sin valor al inicio", saludo[4:])
print("Contar  del final", saludo [5:-1])
# Out:
# ¡Hola a todos, y bienvenidos a iTownGamePlay! Vuestro canal de terror... y diversión
# Primer elemento de la cadena ¡Hol
# Rango de una cadena ¡Hol
# Ultimo elemento n
# Ulitmo elemento n
# Valores en medio, sin especificar ultimo valor  a todos, y bienvenidos a iTownGamePlay! Vuestro canal de terror... y diversión
# Sin valor al inicio a a todos, y bienvenidos a iTownGamePlay! Vuestro canal de terror... y diversión
# Contar  del final  a todos, y bienvenidos a iTownGamePlay! Vuestro canal de terror... y diversió
